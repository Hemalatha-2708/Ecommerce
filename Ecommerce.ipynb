# %%
import pandas as pd

# Load Excel file
df = pd.read_excel("ecommerce_dataset.xlsx")

# Show first rows
print(df.head())
# Out:
#   Order_ID Product_Name  Category   Price  Quantity  Total_Sales  \
# 0  ORD1000   Product_13  Clothing  269.69         1       269.69
# 1  ORD1001   Product_20    Beauty  101.98         1       101.98
# 2  ORD1002    Product_2  Clothing  125.51         1       125.51
# 3  ORD1003    Product_5  Clothing  443.36         5      2216.80
# 4  ORD1004    Product_9    Beauty  281.45         1       281.45
#
#    Customer_Rating Payment_Method Region  Order_Date
# 0              2.5    Credit Card   West       45292
# 1              5.0     Debit Card   West       45293
# 2              4.8     Debit Card   West       45294
# 3              3.5            UPI   East       45295
# 4              4.6     Debit Card   West       45296

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         60 non-null     object
#  1   Product_Name     60 non-null     object
#  2   Category         60 non-null     object
#  3   Price            60 non-null     float64
#  4   Quantity         60 non-null     int64
#  5   Total_Sales      60 non-null     float64
#  6   Customer_Rating  60 non-null     float64
#  7   Payment_Method   60 non-null     object
#  8   Region           60 non-null     object
#  9   Order_Date       60 non-null     int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 4.8+ KB
# None
#             Price   Quantity  Total_Sales  Customer_Rating    Order_Date
# count   60.000000  60.000000    60.000000        60.000000     60.000000
# mean   263.962500   2.800000   761.222500         3.846667  45321.500000
# std    133.810464   1.634376   619.706742         0.739552     17.464249
# min     16.590000   1.000000    16.590000         2.500000  45292.000000
# 25%    160.647500   1.000000   242.302500         3.200000  45306.750000
# 50%    251.320000   3.000000   567.245000         3.900000  45321.500000
# 75%    366.897500   4.250000  1156.175000         4.500000  45336.250000
# max    495.510000   5.000000  2352.350000         5.000000  45351.000000

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], origin='1899-12-30', unit='D')

# %%
df = df.drop(columns=['Order_ID'])

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
X = df.drop(columns=['Total_Sales'])
y = df['Total_Sales']

# %%
print(X.head())
print(y.head())
# Out:
#     Price  Quantity  Customer_Rating Order_Date  Product_Name_Product_10  \
# 0  269.69         1              2.5 2024-01-01                    False
# 1  101.98         1              5.0 2024-01-02                    False
# 2  125.51         1              4.8 2024-01-03                    False
# 3  443.36         5              3.5 2024-01-04                    False
# 4  281.45         1              4.6 2024-01-05                    False
#
#    Product_Name_Product_11  Product_Name_Product_12  Product_Name_Product_13  \
# 0                    False                    False                     True
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    Product_Name_Product_14  Product_Name_Product_15  ...  \
# 0                    False                    False  ...
# 1                    False                    False  ...
# 2                    False                    False  ...
# 3                    False                    False  ...
# 4                    False                    False  ...
#
#    Product_Name_Product_9  Category_Clothing  Category_Electronics  \
# 0                   False               True                 False
# 1                   False              False                 False
# 2                   False               True                 False
# 3                   False               True                 False
# 4                    True              False                 False
#
#    Category_Home  Payment_Method_Credit Card  Payment_Method_Debit Card  \
# 0          False                        True                      False
# 1          False                       False                       True
# 2          False                       False                       True
# 3          False                       False                      False
# 4          False                       False                       True
#
#    Payment_Method_UPI  Region_North  Region_South  Region_West
# 0               False         False         False         True
# 1               False         False         False         True
# 2               False         False         False         True
# 3                True         False         False        False
# 4               False         False         False         True
#
# [5 rows x 32 columns]
# 0     269.69
# 1     101.98
# 2     125.51
# 3    2216.80
# 4     281.45
# Name: Total_Sales, dtype: float64
